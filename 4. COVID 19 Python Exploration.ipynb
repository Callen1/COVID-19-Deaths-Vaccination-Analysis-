# %%
#first import pandas library
import pandas as pd

# %%
#import data for exploration, here data is dataframe
dataframe = pd.read_csv(r"C:\Users\USER\Documents\Callen Study\Portfolio Build\Project 1- COVID 19\Data sets for SQL\COVID Deaths.csv")
#you can name dataframe as mydata, newdata ...of your choice

# %%
#to view data
dataframe
# Out:
#        iso_code continent     location       date  population  total_cases  \
# 0           AFG      Asia  Afghanistan  2/24/2020  38928341.0          1.0
# 1           AFG      Asia  Afghanistan  2/25/2020  38928341.0          1.0
# 2           AFG      Asia  Afghanistan  2/26/2020  38928341.0          1.0
# 3           AFG      Asia  Afghanistan  2/27/2020  38928341.0          1.0
# 4           AFG      Asia  Afghanistan  2/28/2020  38928341.0          1.0
# ...         ...       ...          ...        ...         ...          ...
# 110054      ZWE    Africa     Zimbabwe  8/12/2021  14862927.0     118754.0
# 110055      ZWE    Africa     Zimbabwe  8/13/2021  14862927.0     119508.0
# 110056      ZWE    Africa     Zimbabwe  8/14/2021  14862927.0     119853.0
# 110057      ZWE    Africa     Zimbabwe  8/15/2021  14862927.0     120088.0
# 110058      ZWE    Africa     Zimbabwe  8/16/2021  14862927.0     120088.0
#
# ...

# %%
dataframe.shape
# Out:
# (110059, 26)

# %%
dataframe.index
# Out:
# RangeIndex(start=0, stop=110059, step=1)

# %%
dataframe.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'population',
#        'total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths',
#        'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million'],
#       dtype='object')

# %%
dataframe.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# population                            float64
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# ...

# %%
dataframe.head()
# Out:
#   iso_code continent     location       date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020  38928341.0          1.0
# 1      AFG      Asia  Afghanistan  2/25/2020  38928341.0          1.0
# 2      AFG      Asia  Afghanistan  2/26/2020  38928341.0          1.0
# 3      AFG      Asia  Afghanistan  2/27/2020  38928341.0          1.0
# 4      AFG      Asia  Afghanistan  2/28/2020  38928341.0          1.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        1.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# 2        0.0                 NaN           NaN         NaN  ...
# 3        0.0                 NaN           NaN         NaN  ...
# 4        0.0                 NaN           NaN         NaN  ...
#
#    new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0                              NaN                NaN           NaN
# ...

# %%
dataframe.head(3)
# Out:
#   iso_code continent     location       date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020  38928341.0          1.0
# 1      AFG      Asia  Afghanistan  2/25/2020  38928341.0          1.0
# 2      AFG      Asia  Afghanistan  2/26/2020  38928341.0          1.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        1.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# 2        0.0                 NaN           NaN         NaN  ...
#
#    new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0                              NaN                NaN           NaN
# 1                              NaN                NaN           NaN
# 2                              NaN                NaN           NaN
#
#    icu_patients_per_million  hosp_patients  hosp_patients_per_million  \
# 0                       NaN            NaN                        NaN
# ...

# %%
dataframe.tail(10)
# Out:
#        iso_code continent  location       date  population  total_cases  \
# 110049      ZWE    Africa  Zimbabwe   8/7/2021  14862927.0     115890.0
# 110050      ZWE    Africa  Zimbabwe   8/8/2021  14862927.0     116327.0
# 110051      ZWE    Africa  Zimbabwe   8/9/2021  14862927.0     116853.0
# 110052      ZWE    Africa  Zimbabwe  8/10/2021  14862927.0     117258.0
# 110053      ZWE    Africa  Zimbabwe  8/11/2021  14862927.0     117954.0
# 110054      ZWE    Africa  Zimbabwe  8/12/2021  14862927.0     118754.0
# 110055      ZWE    Africa  Zimbabwe  8/13/2021  14862927.0     119508.0
# 110056      ZWE    Africa  Zimbabwe  8/14/2021  14862927.0     119853.0
# 110057      ZWE    Africa  Zimbabwe  8/15/2021  14862927.0     120088.0
# 110058      ZWE    Africa  Zimbabwe  8/16/2021  14862927.0     120088.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 110049      445.0            1004.286        3826.0        21.0  ...
# ...

# %%
dataframe['continent'].unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
#shows unique values in entire table
dataframe.nunique()
# Out:
# iso_code                                232
# continent                                 6
# location                                232
# date                                    594
# population                              230
# total_cases                           59167
# new_cases                             14039
# new_cases_smoothed                    26978
# total_deaths                          22635
# new_deaths                             3222
# new_deaths_smoothed                    7354
# total_cases_per_million               81978
# new_cases_per_million                 45689
# new_cases_smoothed_per_million        51779
# total_deaths_per_million              51708
# new_deaths_per_million                 8200
# new_deaths_smoothed_per_million        9572
# reproduction_rate                       365
# icu_patients                           2661
# icu_patients_per_million               6211
# hosp_patients                          5248
# ...

# %%
#shows unique values in as SINGLE column
dataframe['date'].nunique()
# Out:
# 594

# %%
 dataframe.count()
# Out:
# iso_code                              110059
# continent                             104976
# location                              110059
# date                                  110059
# population                            109288
# total_cases                           105227
# new_cases                             105224
# new_cases_smoothed                    104214
# total_deaths                           94772
# new_deaths                             94927
# new_deaths_smoothed                   104214
# total_cases_per_million               104670
# new_cases_per_million                 104667
# new_cases_smoothed_per_million        103662
# total_deaths_per_million               94228
# new_deaths_per_million                 94383
# new_deaths_smoothed_per_million       103662
# reproduction_rate                      88702
# icu_patients                           11836
# icu_patients_per_million               11836
# hosp_patients                          14215
# ...

# %%
dataframe['location'].count()
# Out:
# 110059

# %%
dataframe['location'].value_counts()
# Out:
# Mexico                             594
# Peru                               594
# Argentina                          594
# Thailand                           591
# Taiwan                             579
#                                   ...
# Niue                                50
# Tuvalu                              50
# Pitcairn                            49
# Bonaire Sint Eustatius and Saba      1
# Turkmenistan                         1
# Name: location, Length: 232, dtype: int64

# %%
dataframe['continent'].value_counts()
# Out:
# Africa           28113
# Europe           25959
# Asia             25859
# North America    13853
# South America     6536
# Oceania           4656
# Name: continent, dtype: int64
